# %%
# HIDE
import pandas as pd
import numpy as np
np.random.seed(7)
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white", palette=[sns.color_palette('muted')[i] for i in [0,2]], 
        color_codes=True, context="talk")
from IPython import display
# %matplotlib inline

import sklearn as sk
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.utils.class_weight import compute_class_weight  # Estimate class weights for unbalanced datasets
from sklearn.feature_selection import mutual_info_classif

# import keras as ke
# import keras.backend as K
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.models import Model

create_gif = False

print(f"sklearn: {sk.__version__}")
print(f"pandas: {pd.__version__}")
print(f"tensorflow: {tf.__version__}")
# Out:
# sklearn: 1.1.2
# pandas: 1.4.3
# tensorflow: 2.10.0

# %%
column_names = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 
                'marital_status', 'occupation', 'relationship', 'race', 'sex', 
                'capital_gain', 'capital_loss', 'hours_per_week', 'country', 'target']

input_data = (pd.read_csv('E:/canada syntex/Github/fair_classifier_ml/data/adult.data', names=column_names, 
                              na_values="?", sep=r'\s*,\s*', engine='python') # here seperator -- 0 or more whitespace then , then 0 or more whitespace --
                              .loc[lambda df: df['race'].isin(['White', 'Black'])])

input_data = input_data.dropna()    
print(input_data.shape)
# Out:
# (28750, 15)

# %% [markdown]
# ### creating dataset for white race

# %%
white_data = input_data[(input_data["race"]=="White")].drop(columns=['target', 'race', 'sex'])
print(white_data.shape)
white_data.head().T
# Out:
# (25933, 12)
#                             0                   1                  2  \
# age                        39                  50                 38
# workclass           State-gov    Self-emp-not-inc            Private
# fnlwgt                  77516               83311             215646
# education           Bachelors           Bachelors            HS-grad
# education_num              13                  13                  9
# marital_status  Never-married  Married-civ-spouse           Divorced
# occupation       Adm-clerical     Exec-managerial  Handlers-cleaners
# relationship    Not-in-family             Husband      Not-in-family
# capital_gain             2174                   0                  0
# capital_loss                0                   0                  0
# hours_per_week             40                  13                 40
# country         United-States       United-States      United-States
#
#                                  5                   7
# age                             37                  52
# workclass                  Private    Self-emp-not-inc
# fnlwgt                      284582              209642
# education                  Masters             HS-grad
# education_num                   14                   9
# marital_status  Married-civ-spouse  Married-civ-spouse
# occupation         Exec-managerial     Exec-managerial
# relationship                  Wife             Husband
# capital_gain                     0                   0
# capital_loss                     0                   0
# hours_per_week                  40                  45
# country              United-States       United-States

# %%
mut_race = mutual_info_classif(X, Z['race'])

# %% [markdown]
# ### creating dataset for black race

# %%
black_data = input_data[(input_data["race"]=="Black")].drop(columns=['target', 'race', 'sex'])
print(black_data.shape)
black_data.head().T
# Out:
# (2817, 12)
#                                 3                   4                      6   \
# age                             53                  28                     49
# workclass                  Private             Private                Private
# fnlwgt                      234721              338409                 160187
# education                     11th           Bachelors                    9th
# education_num                    7                  13                      5
# marital_status  Married-civ-spouse  Married-civ-spouse  Married-spouse-absent
# occupation       Handlers-cleaners      Prof-specialty          Other-service
# relationship               Husband                Wife          Not-in-family
# capital_gain                     0                   0                      0
# capital_loss                     0                   0                      0
# hours_per_week                  40                  40                     16
# country              United-States                Cuba                Jamaica
#
#                                 10             13
# age                             37             32
# workclass                  Private        Private
# fnlwgt                      280464         205019
# education             Some-college     Assoc-acdm
# education_num                   10             12
# marital_status  Married-civ-spouse  Never-married
# occupation         Exec-managerial          Sales
# relationship               Husband  Not-in-family
# capital_gain                     0              0
# capital_loss                     0              0
# hours_per_week                  80             50
# country              United-States  United-States

# %%
mut_race = mutual_info_classif(X, Z['race'])
mut_sex = mutual_info_classif(X, Z['sex'])
print(mut_race.shape)
print(mut_sex.shape)
# Out:
# (89,)
# (89,)

# %%
# for i, row in X.iterrows():
#     print(i, row)
#     break
